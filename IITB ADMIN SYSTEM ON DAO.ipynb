# %% [markdown]
# # Shri Ganeshaya Namah

# %% [markdown]
# ## Goals
#  - Courses feedback
#  - Mess food quantity
#  - MoodI, TF and Ecell money
#  - Sports and cult money
#  - Tech teams funding

# %% [markdown]
# ## ID / PublicKeys / PrivateKeys
#  - OTP (P=process) whenever you login to ASC through DAO portal and then it will send a encrypted 64 bit data (named 'ID') having cpi, roll no. and a Authentication key {to ensure if it is the right asc portal} and ASC portal will display a public key, a private key and a security key which you need to store locally
#  - private key is to extract roll no. from ID
#  - public key is to extract cpi from ID
#  - security key is to ensure if the concerned person has entered the ID

# %%
# pseudo code
*/
# At DAO portal
if(toggle):
    vist(asc.iitb.ac.in)
    receive(Data_64bit)

# At ASC
if(toggle):
    send(encryption(Roll no. , CPI, authenticationKey))
    display(Public, Private, Security)

# At DAO portal
display(scene_login)
/*

# %% [markdown]
# # Course Feedback

# %% [markdown]
# ## Need and Impact
#  - The Current course feedback system is completely useless, to make it more dynamic and completely anonymous; I have developed a system to change/modify the course policy based on various parameters cpi normal distribution.
#
#
# ## Algorithm and policy
#  - This dynamic algorithm is to modify the course policy at any time : course_content/ grading_policy/ exam_logistics
#  - All the members (students) will be anonymous and their votes will have weightage based on a gaussian distribution with independent parameter as CPI
#  - Any member can raise a poll atmost 7 times in half semester
#  - It is must for every member to check the poll section once in a day

# %%
# pseudo code
*/ 
def scale():
    norm=normal_dis(5,10) %(minCPI, maxCPI)
    scale(norm.height(cpi))

generatePoll()
rcd=receive(vote,ID,Public,Security)
if(decrytion(ID,Security)==True):
    switch(case):
        case=opinion1 : vote_opinion_1 + scale(decrypt(ID, private))
            break;
        case=opinion2 : vote_opinion_2 + scale(decrypt(ID, private))
            break;
        case=opinion3 : vote_opinion_3 + scale(decrypt(ID, private))
            break;
        
else:
    display('wrong credentials')*

# %% [markdown]
# ![Screenshot%202022-07-20%20231458.png](attachment:Screenshot%202022-07-20%20231458.png)

# %% [markdown]
# ## Mess Food

# %% [markdown]
# ## Need and Impact
#  - So much mess food is getting wasted everyday and most students don't get benefitted of what they pay; so for the good of both mess company and students, I have developed a system which uses machine learning to generate_mess_menu,
#
# ## Algorithm and Policy
#  - Every person will have the option to choose to eat or not to eat in mess for next 3 days.
#  - Payment will be cost * no. of days eaten + $x$% of cost * no. of days food not eaten. where $x<1$
#  - An ML based algorithm will keep track quantity of food eaten
#  - The autonoums organisation will design the menu based on data analysis
#  - Measuring quantity will require some weighing machines, Spicy will have score based on $scoville-scale$
#   ref: https://www.masterclass.com/articles/a-guide-to-the-scoville-scale#:~:text=The%20Scoville%20scale%20is%20a,Scoville%20Heat%20Units%20(SHUs)

# %% [markdown]
# ![mess_dao.drawio.png](attachment:mess_dao.drawio.png)

# %% [markdown]
# ## MoodI, TF, ECELL money

# %% [markdown]
# ## Need and Impact
#  - These IBs get a large amount of money from their sponsorships by hard-work of students. To optimize the regulation process and maintaining transparency; a system to
#  -
